# %%
import os
import json
import pandas as pd
import geopandas as gpd
import re
import numpy as np

# %% [markdown]
# ### Definitions

# %%
# dictionary definitions

json_data_dic = {0: "blds_continent_data_18-23_ai.json",
            1: "blds_africa_states_18-23_ai.json",
            2: "blds_northamerica_states_18-23_ai.json",
            3: "blds_europe_states_18-23_ai.json",
            4: "blds_asia_states_18-23_ai.json",
            
            }

shp_dic = {0: "contionents-borders.shp",
                      1: "africa-states-borders.shp",
                      2: "northamerica-states-borders.shp",
                      3: "europe-states-borders.shp",
                      4: "asia-states-borders.shp",}

geojson_folder_dic = {0: "geojson-continent-states",
                      1: "geojson-africa-states",
                      2: "geojson-northamerica-states",
                      3: "geojson-europe-states",
                      4: "geojson-asia-states",}

# %%
# user input definition - json data

while True:
    try:
        user_json_spec = int(input("Which data do you want to join?\
                            Enter 0 for blds by continents (2018–2023),\
                            1 for blds by Africa states (2018–2023),\
                            2 for blds by North-Central America states (2018–2023),\
                            3 for blds by Europe states (2018–2023),\
                            4 for blds by Asia states (2018–2023),\
                                :"
                                ))
    except ValueError:
        print("Please enter a number.")
        continue
    if user_json_spec not in range(len(json_data_dic)):
        print(f"Please enter one of these numbers: {json_data_dic.keys()}.")
        continue
    break

# %%
# user input definition - spatial data to conect

while True:
    try:
        user_spatial = int(input("Which data do you want to plot?\
                            Enter 0 for stats by continents (2018–2023),\
                            1 for stats by Africa states (2018–2023),\
                            2 for stats by North-Central America states (2018–2023),\
                            3 for stats by Europe states (2018–2023),\
                            4 for stats by Asia states (2018–2023):"
                                ))
    except ValueError:
        print("Please enter a number.")
        continue
    if user_spatial not in range(len(shp_dic)):
        print(f"Please enter one of these numbers: {shp_dic.keys()}.")
        continue
    break

# %% [markdown]
# #### Read the downloaded/nonspatial and spatial data

# %%
os.chdir('..')
home_dir = os.getcwd()
ns_d_path = os.path.join(home_dir, "downloaded-data", "")
s_d_path = os.path.join(home_dir, "shp", "")

# %%
# replace... blds_continents_data_18-23_ai.json; blds_africa_states_18-23_ai.json; blds_northamerica_states_18-23_ai.json
with open(f"{ns_d_path}{json_data_dic[user_json_spec]}", "r") as f:
    ns_d = json.load(f)
# ns_d

# %%
ns_d
# Out:
# [[{'groupByObject': [0, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 61906.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 76289.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 86564.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 106221.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 134409.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 149282.0}]},
#   {'groupByObject': [0, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 150.0}]}],
#  [{'groupByObject': [10, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 781204.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 964440.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 1046593.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 1123752.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 1241943.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 2521911.0}]},
#   {'groupByObject': [10, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 94.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 308.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 1698.0}]}],
#  [{'groupByObject': [11, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 41155.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 46221.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 60876.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 112184.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 138764.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 147207.0}]},
#   {'groupByObject': [11, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 0.0}]}],
#  [{'groupByObject': [12, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 26159.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 40036.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 49245.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 97935.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 140504.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 158691.0}]},
#   {'groupByObject': [12, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 2438.0}]}],
#  [{'groupByObject': [13, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 46507.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 48081.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 73376.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 81821.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 91080.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 92148.0}]},
#   {'groupByObject': [13, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 0.0}]}],
#  [{'groupByObject': [14, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 8207.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 14042.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 29205.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 47184.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 98911.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 100201.0}]},
#   {'groupByObject': [14, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 241.0}]}],
#  [{'groupByObject': [15, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 12368.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 27441.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 33911.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 37690.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 42075.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 42312.0}]},
#   {'groupByObject': [15, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 69.0}]}],
#  [{'groupByObject': [16, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 8823.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 13269.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 18685.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 21565.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 29268.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 30477.0}]},
#   {'groupByObject': [16, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 63.0}]}],
#  [{'groupByObject': [17, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 13222.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 13827.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 14326.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 54377.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 148907.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 149121.0}]},
#   {'groupByObject': [17, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 17.0}]}],
#  [{'groupByObject': [18, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 26832.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 27155.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 28675.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 29592.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 38960.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 51130.0}]},
#   {'groupByObject': [18, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 34.0}]}],
#  [{'groupByObject': [19, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 30154.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 30152.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 30160.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 30188.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 30290.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 30418.0}]},
#   {'groupByObject': [19, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 0.0}]}],
#  [{'groupByObject': [1, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 65513.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 94724.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 109674.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 135588.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 144033.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 148643.0}]},
#   {'groupByObject': [1, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 187.0}]}],
#  [{'groupByObject': [20, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 38555.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 38930.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 39053.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 38941.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 39085.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 39148.0}]},
#   {'groupByObject': [20, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 0.0}]}],
#  [{'groupByObject': [21, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 4448.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 4540.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 6579.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 8630.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 8780.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 8930.0}]},
#   {'groupByObject': [21, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 0.0}]}],
#  [{'groupByObject': [22, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 80656.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 86509.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 92912.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 955408.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 972548.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 972820.0}]},
#   {'groupByObject': [22, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 23.0}]}],
#  [{'groupByObject': [23, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 0.0}]}],
#  [{'groupByObject': [24, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 0.0}]}],
#  [{'groupByObject': [2, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 796180.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 863815.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 949087.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 996522.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 1212891.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 1226088.0}]},
#   {'groupByObject': [2, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 1.0}]}],
#  [{'groupByObject': [3, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 57315.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 65188.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 74797.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 82728.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 101317.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 125113.0}]},
#   {'groupByObject': [3, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 237.0}]}],
#  [{'groupByObject': [4, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 37175.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 66505.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 73746.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 81073.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 87442.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 260645.0}]},
#   {'groupByObject': [4, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 2100.0}]}],
#  [{'groupByObject': [5, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 531090.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 563352.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 569021.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 578475.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 1758358.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 3335524.0}]},
#   {'groupByObject': [5, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 1488.0}]}],
#  [{'groupByObject': [6, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 183932.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 223608.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 242075.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 294416.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 329090.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 354131.0}]},
#   {'groupByObject': [6, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 14652.0}]}],
#  [{'groupByObject': [7, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 203120.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 216651.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 448302.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 554001.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 669917.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 676925.0}]},
#   {'groupByObject': [7, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 4054.0}]}],
#  [{'groupByObject': [8, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 23345812.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 27680676.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 33270905.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 38617428.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 43771125.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 49535224.0}]},
#   {'groupByObject': [8, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 13935.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 2271557.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 5258855.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 8366550.0}]}],
#  [{'groupByObject': [9, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 2096238.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 2731484.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 4026234.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 5170070.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 5318865.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 5638598.0}]},
#   {'groupByObject': [9, 'source=microsoft/BuildingFootprints'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 39290.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 110173.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 162750.0}]}]]

# %%
os.getcwd()
# Out:
# 'c:\\Users\\milan\\OneDrive - MUNI\\VŠ\\PhD\\Zahraniční stáž\\Work\\HeiGIT_notebooks\\analysis\\ai-assisted-osm-mapping-stats'

# %%
# change name of the layer - africa-states-borders.shp; northamerica-states-borders.shp

s_df = gpd.read_file(f"{s_d_path}{shp_dic[user_spatial]}")
# s_df["s_id"] = s_df.index
s_df.head()
# Out:
#            SOVEREIGNT  LEVEL               TYPE               ADMIN  \
# 0          Costa Rica      2  Sovereign country          Costa Rica
# 1           Nicaragua      2  Sovereign country           Nicaragua
# 2               Haiti      2  Sovereign country               Haiti
# 3  Dominican Republic      2  Sovereign country  Dominican Republic
# 4         El Salvador      2  Sovereign country         El Salvador
#
#              NAME      CONTINENT             NAME_EN  \
# 0      Costa Rica  North America          Costa Rica
# 1       Nicaragua  North America           Nicaragua
# 2           Haiti  North America               Haiti
# 3  Dominican Rep.  North America  Dominican Republic
# 4     El Salvador  North America         El Salvador
#
#                                             geometry
# 0  MULTIPOLYGON (((-83.69650 10.93659, -83.68687 ...
# 1  MULTIPOLYGON (((-85.70174 11.08088, -85.70242 ...
# 2  MULTIPOLYGON (((-71.75744 19.71011, -71.74861 ...
# 3  MULTIPOLYGON (((-71.75744 19.71011, -71.73827 ...
# 4  MULTIPOLYGON (((-90.09831 13.73140, -90.11431 ...

# %% [markdown]
# #### Edit the obtained data into desired shape to create a DataFrame

# %%
d = {
    "feature": [],
    "source": [],
    "timestamp": [],
    "value": []
}

# %%
for region in ns_d:
    for dic1 in region:
        feature, source = dic1["groupByObject"][0], dic1["groupByObject"][1]
        for res in dic1["result"]:
            d["feature"].append(feature)
            d["source"].append(source)
            d["timestamp"].append(res["timestamp"])
            d["value"].append(res["value"])

ns_df = pd.DataFrame(d)
# ns_df

# %%
# extract only the year
ns_df["year"] = pd.to_datetime(ns_df["timestamp"]).dt.year

# %%
ns_df
# Out:
#      feature                               source             timestamp  \
# 0          0                            remainder  2018-01-01T00:00:00Z
# 1          0                            remainder  2019-01-01T00:00:00Z
# 2          0                            remainder  2020-01-01T00:00:00Z
# 3          0                            remainder  2021-01-01T00:00:00Z
# 4          0                            remainder  2022-01-01T00:00:00Z
# ..       ...                                  ...                   ...
# 283        9  source=microsoft/BuildingFootprints  2019-01-01T00:00:00Z
# 284        9  source=microsoft/BuildingFootprints  2020-01-01T00:00:00Z
# 285        9  source=microsoft/BuildingFootprints  2021-01-01T00:00:00Z
# 286        9  source=microsoft/BuildingFootprints  2022-01-01T00:00:00Z
# 287        9  source=microsoft/BuildingFootprints  2023-01-01T00:00:00Z
#
#         value  year
# 0     61906.0  2018
# 1     76289.0  2019
# 2     86564.0  2020
# 3    106221.0  2021
# 4    134409.0  2022
# ..        ...   ...
# 283       0.0  2019
# 284       0.0  2020
# 285   39290.0  2021
# 286  110173.0  2022
# 287  162750.0  2023
#
# [288 rows x 5 columns]

# %% [markdown]
# #### Append the names of the regions and numbers to the DataFrame

# %%
# replace... geojson-continent-borders, geojson-africa-states; geojson-northamerica-states
geojson_dir = os.path.join(home_dir, f"{geojson_folder_dic[user_spatial]}", "")

geojson_names = []
for (dir_path, dir_names, file_names) in os.walk(geojson_dir):  # give the path
    geojson_names.extend(file_names)
print(geojson_names)
print(os.getcwd())
# Out:
# ['0_Costa Rica.geojson', '10_Mexico.geojson', '11_Belize.geojson', '12_Panama.geojson', '13_Bahamas.geojson', '14_Trinidad and Tobago.geojson', '15_Grenada.geojson', '16_St. Vin. and Gren..geojson', '17_Barbados.geojson', '18_Saint Lucia.geojson', '19_Dominica.geojson', '1_Nicaragua.geojson', '20_Antigua and Barb..geojson', '21_St. Kitts and Nevis.geojson', '22_Jamaica.geojson', '23_Bajo Nuevo Bank.geojson', '24_Serranilla Bank.geojson', '2_Haiti.geojson', '3_Dominican Rep..geojson', '4_El Salvador.geojson', '5_Guatemala.geojson', '6_Cuba.geojson', '7_Honduras.geojson', '8_United States of America.geojson', '9_Canada.geojson']
# c:\Users\milan\OneDrive - MUNI\VŠ\PhD\Zahraniční stáž\Work\HeiGIT_notebooks\analysis\ai-assisted-osm-mapping-stats

# %%
geojson_names_2 = geojson_names

id_name_dic = {int(re.search(r'^\d+', k)[0]): re.search(r'\_.+\.', v)[0][1:-1]
                for k, v in zip(geojson_names, geojson_names_2)}
id_name_ser = pd.Series(id_name_dic)
id_name_df = pd.DataFrame(id_name_ser, columns=["name"])
id_name_df = id_name_df.reset_index().rename(columns={"index": "id"})
id_name_df["id"] = id_name_df["id"].astype(int)
# id_name_df

# %%
id_name_df
# Out:
#     id                      name
# 0    0                Costa Rica
# 1   10                    Mexico
# 2   11                    Belize
# 3   12                    Panama
# 4   13                   Bahamas
# 5   14       Trinidad and Tobago
# 6   15                   Grenada
# 7   16        St. Vin. and Gren.
# 8   17                  Barbados
# 9   18               Saint Lucia
# 10  19                  Dominica
# 11   1                 Nicaragua
# 12  20         Antigua and Barb.
# 13  21       St. Kitts and Nevis
# 14  22                   Jamaica
# 15  23           Bajo Nuevo Bank
# 16  24           Serranilla Bank
# 17   2                     Haiti
# 18   3            Dominican Rep.
# 19   4               El Salvador
# 20   5                 Guatemala
# 21   6                      Cuba
# 22   7                  Honduras
# 23   8  United States of America
# 24   9                    Canada

# %%
# merge df with region names based on ids
ns_df = ns_df.merge(id_name_df, how="left", left_on="feature",
               right_on="id")
ns_df.head(20)
# Out:
#     feature                               source             timestamp  \
# 0         0                            remainder  2018-01-01T00:00:00Z
# 1         0                            remainder  2019-01-01T00:00:00Z
# 2         0                            remainder  2020-01-01T00:00:00Z
# 3         0                            remainder  2021-01-01T00:00:00Z
# 4         0                            remainder  2022-01-01T00:00:00Z
# 5         0                            remainder  2023-01-01T00:00:00Z
# 6         0  source=microsoft/BuildingFootprints  2018-01-01T00:00:00Z
# 7         0  source=microsoft/BuildingFootprints  2019-01-01T00:00:00Z
# 8         0  source=microsoft/BuildingFootprints  2020-01-01T00:00:00Z
# 9         0  source=microsoft/BuildingFootprints  2021-01-01T00:00:00Z
# 10        0  source=microsoft/BuildingFootprints  2022-01-01T00:00:00Z
# 11        0  source=microsoft/BuildingFootprints  2023-01-01T00:00:00Z
# 12       10                            remainder  2018-01-01T00:00:00Z
# 13       10                            remainder  2019-01-01T00:00:00Z
# 14       10                            remainder  2020-01-01T00:00:00Z
# 15       10                            remainder  2021-01-01T00:00:00Z
# 16       10                            remainder  2022-01-01T00:00:00Z
# 17       10                            remainder  2023-01-01T00:00:00Z
# 18       10  source=microsoft/BuildingFootprints  2018-01-01T00:00:00Z
# 19       10  source=microsoft/BuildingFootprints  2019-01-01T00:00:00Z
#
#         value  year  id        name
# 0     61906.0  2018   0  Costa Rica
# 1     76289.0  2019   0  Costa Rica
# 2     86564.0  2020   0  Costa Rica
# 3    106221.0  2021   0  Costa Rica
# 4    134409.0  2022   0  Costa Rica
# 5    149282.0  2023   0  Costa Rica
# 6         0.0  2018   0  Costa Rica
# 7         0.0  2019   0  Costa Rica
# 8         0.0  2020   0  Costa Rica
# 9         0.0  2021   0  Costa Rica
# 10        0.0  2022   0  Costa Rica
# 11      150.0  2023   0  Costa Rica
# 12   781204.0  2018  10      Mexico
# 13   964440.0  2019  10      Mexico
# 14  1046593.0  2020  10      Mexico
# 15  1123752.0  2021  10      Mexico
# 16  1241943.0  2022  10      Mexico
# 17  2521911.0  2023  10      Mexico
# 18        0.0  2018  10      Mexico
# 19        0.0  2019  10      Mexico

# %%
ns_df.loc[ns_df.isna().any(axis=1),:]
# Out:
# Empty DataFrame
# Columns: [feature, source, timestamp, value, year, id, name]
# Index: []

# %%
# ns_df.sort_values(by=["value"], ascending=False, inplace=False).head(20)

# %% [markdown]
# #### Data preparation and filtering

# %%
# get the number of AI Microsoft (source=microsoft/BuildingFootprints) / manually mapped (remainder) buildings for every year
grouped = ns_df.groupby(["name", "year"])["value"].sum()
# grouped

# %%
# merge the DataFrame with groupBy DataFrame and compute the percentage
merged_data = ns_df.merge(grouped, on=["name", 'year'], how='left', )
merged_data = merged_data.rename(columns={"value_x":"num_of_blds", "value_y":"total_blds"})
merged_data["percentage"] = (merged_data["num_of_blds"] / merged_data["total_blds"]) * 100
# merged_data.head(10)

# %%
# percentage verification
merged_data.groupby(["name", "year"])["percentage"].sum()
# Out:
# name                      year
# Antigua and Barb.         2018    100.0
#                           2019    100.0
#                           2020    100.0
#                           2021    100.0
#                           2022    100.0
#                                   ...
# United States of America  2019    100.0
#                           2020    100.0
#                           2021    100.0
#                           2022    100.0
#                           2023    100.0
# Name: percentage, Length: 150, dtype: float64

# %%
ns_df_rem = merged_data.loc[merged_data["source"] == "remainder", :]
ns_df_ai = merged_data.loc[merged_data["source"] == "source=microsoft/BuildingFootprints", :]

# %%
ns_df_rem_sel = ns_df_rem.groupby("name")[["num_of_blds", "year", "percentage", "total_blds"]].last().reset_index()
ns_df_ai_sel = ns_df_ai.groupby("name")[["num_of_blds", "year", "percentage", "total_blds"]].last().reset_index()
ns_df_ai_sel.head()
# Out:
#                 name  num_of_blds  year  percentage  total_blds
# 0  Antigua and Barb.          0.0  2023    0.000000     39148.0
# 1            Bahamas          0.0  2023    0.000000     92148.0
# 2    Bajo Nuevo Bank          0.0  2023         NaN         0.0
# 3           Barbados         17.0  2023    0.011399    149138.0
# 4             Belize          0.0  2023    0.000000    147207.0

# %%
ns_df_rem_sel.head()
# Out:
#                 name  num_of_blds  year  percentage  total_blds
# 0  Antigua and Barb.      39148.0  2023  100.000000     39148.0
# 1            Bahamas      92148.0  2023  100.000000     92148.0
# 2           Barbados     149121.0  2023   99.988601    149138.0
# 3             Belize     147207.0  2023  100.000000    147207.0
# 4             Canada    5638598.0  2023   97.194618   5801348.0

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
s_df.head(2)
# Out:
#    SOVEREIGNT  LEVEL               TYPE       ADMIN        NAME  \
# 0  Costa Rica      2  Sovereign country  Costa Rica  Costa Rica
# 1   Nicaragua      2  Sovereign country   Nicaragua   Nicaragua
#
#        CONTINENT     NAME_EN  \
# 0  North America  Costa Rica
# 1  North America   Nicaragua
#
#                                             geometry
# 0  MULTIPOLYGON (((-83.69650 10.93659, -83.68687 ...
# 1  MULTIPOLYGON (((-85.70174 11.08088, -85.70242 ...

# %%
merged_d_rem = s_df.merge(ns_df_rem_sel, how="left",
                          left_on="NAME", right_on="name").rename(columns={"name_y": "added_name"})  # change left_on
merged_d_ai = s_df.merge(ns_df_ai_sel, how="left",
                         left_on="NAME", right_on="name").rename(columns={"name_y": "added_name"})  # change left_on
merged_d_rem.head(2)
# Out:
#    SOVEREIGNT  LEVEL               TYPE       ADMIN        NAME  \
# 0  Costa Rica      2  Sovereign country  Costa Rica  Costa Rica
# 1   Nicaragua      2  Sovereign country   Nicaragua   Nicaragua
#
#        CONTINENT     NAME_EN  \
# 0  North America  Costa Rica
# 1  North America   Nicaragua
#
#                                             geometry        name  num_of_blds  \
# 0  MULTIPOLYGON (((-83.69650 10.93659, -83.68687 ...  Costa Rica     149282.0
# 1  MULTIPOLYGON (((-85.70174 11.08088, -85.70242 ...   Nicaragua     148643.0
#
#      year  percentage  total_blds
# 0  2023.0   99.899620    149432.0
# 1  2023.0   99.874353    148830.0

# %%
# verify the merge is successful
merged_d_rem.loc[merged_d_rem.isna().any(axis=1),:]
# Out:
#                       SOVEREIGNT  LEVEL           TYPE  \
# 23  Bajo Nuevo Bank (Petrel Is.)      2  Indeterminate
# 24               Serranilla Bank      2  Indeterminate
#
#                            ADMIN             NAME      CONTINENT  \
# 23  Bajo Nuevo Bank (Petrel Is.)  Bajo Nuevo Bank  North America
# 24               Serranilla Bank  Serranilla Bank  North America
#
#             NAME_EN                                           geometry name  \
# 23  Bajo Nuevo Bank  POLYGON ((-79.98929 15.79495, -79.98782 15.796...  NaN
# 24  Serranilla Bank  POLYGON ((-78.63707 15.86209, -78.64041 15.864...  NaN
#
#     num_of_blds  year  percentage  total_blds
# 23          NaN   NaN         NaN         NaN
# 24          NaN   NaN         NaN         NaN

# %%
merged_d_ai.head(2)
# Out:
#    SOVEREIGNT  LEVEL               TYPE       ADMIN        NAME  \
# 0  Costa Rica      2  Sovereign country  Costa Rica  Costa Rica
# 1   Nicaragua      2  Sovereign country   Nicaragua   Nicaragua
#
#        CONTINENT     NAME_EN  \
# 0  North America  Costa Rica
# 1  North America   Nicaragua
#
#                                             geometry        name  num_of_blds  \
# 0  MULTIPOLYGON (((-83.69650 10.93659, -83.68687 ...  Costa Rica        150.0
# 1  MULTIPOLYGON (((-85.70174 11.08088, -85.70242 ...   Nicaragua        187.0
#
#    year  percentage  total_blds
# 0  2023    0.100380    149432.0
# 1  2023    0.125647    148830.0

# %%
print(merged_d_rem.columns)
print(merged_d_ai.columns)
# Out:
# Index(['SOVEREIGNT', 'LEVEL', 'TYPE', 'ADMIN', 'NAME', 'CONTINENT', 'NAME_EN',
#        'geometry', 'name', 'num_of_blds', 'year', 'percentage', 'total_blds'],
#       dtype='object')
# Index(['SOVEREIGNT', 'LEVEL', 'TYPE', 'ADMIN', 'NAME', 'CONTINENT', 'NAME_EN',
#        'geometry', 'name', 'num_of_blds', 'year', 'percentage', 'total_blds'],
#       dtype='object')

# %% [markdown]
# #### Export the data into layers

# %%
os.getcwd()
# Out:
# 'c:\\Users\\milan\\OneDrive - MUNI\\VŠ\\PhD\\Zahraniční stáž\\Work\\HeiGIT_notebooks\\analysis\\ai-assisted-osm-mapping-stats'

# %%
# change name of the layer
merged_d_rem.to_file(f"maps/shp/mm_blds_{geojson_folder_dic[user_json_spec][8:]}_18-21.shp", driver='ESRI Shapefile')
# Out:
# C:\Users\milan\AppData\Local\Temp\ipykernel_7632\2539111951.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   merged_d_rem.to_file(f"maps/shp/mm_blds_{geojson_folder_dic[user_json_spec][8:]}_18-21.shp", driver='ESRI Shapefile')

# %%
# change name of the layer
merged_d_ai.to_file(f"maps/shp/ai_blds_{geojson_folder_dic[user_json_spec][8:]}_18-21.shp", driver='ESRI Shapefile')
# Out:
# C:\Users\milan\AppData\Local\Temp\ipykernel_7632\2309810475.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   merged_d_ai.to_file(f"maps/shp/ai_blds_{geojson_folder_dic[user_json_spec][8:]}_18-21.shp", driver='ESRI Shapefile')
