# %%
import os
import json
import pandas as pd
import geopandas as gpd
import re
import numpy as np

# %% [markdown]
# ### Definitions

# %%
# dictionary definitions

json_data_dic = {
            0: "roads_continent_data_18-23_ai.json",
            1: "roads_africa_states_18-23_ai.json",
            2: "roads_northamerica_states_18-23_ai.json",
            3: "roads_europe_states_18-23_ai.json",
            4: "roads_asia_states_18-23_ai.json",
            }

shp_dic = {
            0: "contionents-borders.shp",
            1: "africa-states-borders.shp",
            2: "northamerica-states-borders.shp",
            3: "europe-states-borders.shp",
            4: "asia-states-borders.shp",
                      }

geojson_folder_dic = {
                    0: "geojson-continent-states",
                    1: "geojson-africa-states",
                    2: "geojson-northamerica-states",
                    3: "geojson-europe-states",
                    4: "geojson-asia-states",
                      }

# %%
# user input definition - json data

while True:
    try:
        user_json_spec = int(input("Which data do you want to join?\
                            Enter a number:\
                            0 for roads by continents (2018–2023),\
                            1 for roads by Africa states (2018–2023),\
                            2 for roads by North-Central America states (2018–2023),\
                            3 for roads by Europe states (2018–2023),\
                            4 for roads by Asia states (2018–2023),\
                                :"
                                ))
    except ValueError:
        print("Please enter a number.")
        continue
    if user_json_spec not in range(len(json_data_dic)):
        print(f"Please enter one of these numbers: {json_data_dic.keys()}.")
        continue
    break

# %%
# user input definition - spatial data to conect

while True:
    try:
        user_spatial = int(input("Which data do you want to plot?\
                            Enter 0 for stats by continents (2018–2023),\
                            1 for stats by Africa states (2018–2023),\
                            2 for stats by North-Central America states (2018–2023),\
                            3 for stats by Europe states (2018–2023),\
                            4 for stats by Asia states (2018–2023):"
                                ))
    except ValueError:
        print("Please enter a number.")
        continue
    if user_spatial not in range(len(shp_dic)):
        print(f"Please enter one of these numbers: {shp_dic.keys()}.")
        continue
    break

# %% [markdown]
# #### Read the downloaded/nonspatial and spatial data

# %%
os.chdir('..')
home_dir = os.getcwd()
ns_d_path = os.path.join(home_dir, "downloaded-data", "")
s_d_path = os.path.join(home_dir, "shp", "")

# %%
# replace... blds_continents_data_18-23_ai.json; blds_africa_states_18-23_ai.json; blds_northamerica_states_18-23_ai.json
with open(f"{ns_d_path}{json_data_dic[user_json_spec]}", "r") as f:
    ns_d = json.load(f)
# ns_d

# %%
ns_d
# Out:
# [[{'groupByObject': [0, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 412573538.52},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 729335700.28},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 1096717478.93},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 1206910324.62},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 1246753928.28},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 1255846149.67}]},
#   {'groupByObject': [0, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 8588.36},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 34164.54},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 2673150.37},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 3060945.91}]}],
#  [{'groupByObject': [10, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 9869635.94},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 10869145.23},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 11872015.36},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 12224539.33},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 24163331.31},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 25305334.07}]},
#   {'groupByObject': [10, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 8853.02},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 90723.13},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 164251.5}]}],
#  [{'groupByObject': [11, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 61074682.51},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 66853997.32},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 71251061.16},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 73665680.95},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 86199137.72},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 88443600.63}]},
#   {'groupByObject': [11, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 8364.55},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 8363.23},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 8771.1}]}],
#  [{'groupByObject': [12, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value':

#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 6014618.72},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 8183779.28},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 9057137.01},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 9193144.14}]},
#   {'groupByObject': [49, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 0.0}]}],
#  [{'groupByObject': [4, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 2245231727.46},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 2573518524.3},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 2884887025.91},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 3315036911.64},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 3693763753.49},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 4067592317.98}]},
#   {'groupByObject': [4, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 19158935.43},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 61602660.73},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 84541119.12}]}],
#  [{'groupByObject': [50, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 4504978.81},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 4866504.42},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 5058890.04},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 5157387.23},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 5317837.53},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 5540932.88}]},
#   {'groupByObject': [50, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 322.18}]}],
#  [{'groupByObject': [51, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 1261.15},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 1267.32},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 1267.32}]},
#   {'groupByObject': [51, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 0.0}]}],
#  [{'groupByObject': [52, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 0.0}]}],
#  [{'groupByObject': [5, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 87848347.99},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 91021213.12},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 93005876.3},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 95739319.03},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 98199771.46},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 102189027.71}]},
#   {'groupByObject': [5, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 15867.03},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 37074.4},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 79110.68}]}],
#  [{'groupByObject': [6, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 20818755.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 21521425.13},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 36953762.29},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 37882359.11},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 39744844.8},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 41500445.11}]},
#   {'groupByObject': [6, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 176227.5},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 178854.46},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 180039.85}]}],
#  [{'groupByObject': [7, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 117465226.17},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 122338577.47},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 127114747.26},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 130540473.01},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 133094848.77},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 134295194.01}]},
#   {'groupByObject': [7, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 127988.93},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 146522.15},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 146399.75}]}],
#  [{'groupByObject': [8, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 169291508.73},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 184980161.95},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 198165935.28},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 214301786.98},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 234242136.02},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 257232289.6}]},
#   {'groupByObject': [8, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 507277.25},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 1847379.02},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 4933627.12}]}],
#  [{'groupByObject': [9, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 53888314.13},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 58065710.79},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 63221517.24},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 72082028.98},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 76893539.05},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 86751935.99}]},
#   {'groupByObject': [9, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 8688.68},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 19867.31},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 44029.73}]}]]

# %%
os.getcwd()
# Out:
# 'c:\\Users\\milan\\OneDrive - MUNI\\VŠ\\PhD\\Zahraniční stáž\\Work\\HeiGIT_notebooks\\analysis\\ai-assisted-osm-mapping-stats'

# %%
# change name of the layer - africa-states-borders.shp; northamerica-states-borders.shp

s_df = gpd.read_file(f"{s_d_path}{shp_dic[user_spatial]}")
# s_df["s_id"] = s_df.index
s_df.head()
# Out:
#   SOVEREIGNT  LEVEL               TYPE      ADMIN       NAME CONTINENT  \
# 0  Indonesia      2  Sovereign country  Indonesia  Indonesia      Asia
# 1   Malaysia      2  Sovereign country   Malaysia   Malaysia      Asia
# 2     Cyprus      2  Sovereign country     Cyprus     Cyprus      Asia
# 3      India      2  Sovereign country      India      India      Asia
# 4      China      1        Sovereignty      China      China      Asia
#
#                       NAME_EN  \
# 0                   Indonesia
# 1                    Malaysia
# 2                      Cyprus
# 3                       India
# 4  People's Republic of China
#
#                                             geometry
# 0  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...
# 2  MULTIPOLYGON (((33.78183 34.97622, 33.78094 34...
# 3  MULTIPOLYGON (((77.80035 35.49541, 77.81533 35...
# 4  MULTIPOLYGON (((78.91769 33.38626, 78.91595 33...

# %% [markdown]
# #### Edit the obtained data into desired shape to create a DataFrame

# %%
d = {
    "feature": [],
    "source": [],
    "timestamp": [],
    "value": []
}

# %%
for region in ns_d:
    for dic1 in region:
        feature, source = dic1["groupByObject"][0], dic1["groupByObject"][1]
        for res in dic1["result"]:
            d["feature"].append(feature)
            d["source"].append(source)
            d["timestamp"].append(res["timestamp"])
            d["value"].append(res["value"])

ns_df = pd.DataFrame(d)
# ns_df

# %%
# extract only the year
ns_df["year"] = pd.to_datetime(ns_df["timestamp"]).dt.year

# convert meters to kilometers
ns_df["value_km"] = ns_df["value"] / 1000

# %%
ns_df
# Out:
#      feature        source             timestamp         value  year  \
# 0          0     remainder  2018-01-01T00:00:00Z  4.125735e+08  2018
# 1          0     remainder  2019-01-01T00:00:00Z  7.293357e+08  2019
# 2          0     remainder  2020-01-01T00:00:00Z  1.096717e+09  2020
# 3          0     remainder  2021-01-01T00:00:00Z  1.206910e+09  2021
# 4          0     remainder  2022-01-01T00:00:00Z  1.246754e+09  2022
# ..       ...           ...                   ...           ...   ...
# 625        9  source=maxar  2019-01-01T00:00:00Z  0.000000e+00  2019
# 626        9  source=maxar  2020-01-01T00:00:00Z  0.000000e+00  2020
# 627        9  source=maxar  2021-01-01T00:00:00Z  8.688680e+03  2021
# 628        9  source=maxar  2022-01-01T00:00:00Z  1.986731e+04  2022
# 629        9  source=maxar  2023-01-01T00:00:00Z  4.402973e+04  2023
#
#          value_km
# 0    4.125735e+05
# 1    7.293357e+05
# 2    1.096717e+06
# 3    1.206910e+06
# 4    1.246754e+06
# ..            ...
# 625  0.000000e+00
# 626  0.000000e+00
# 627  8.688680e+00
# 628  1.986731e+01
# 629  4.402973e+01
#
# [630 rows x 6 columns]

# %% [markdown]
# #### Append the names of the regions and numbers to the DataFrame

# %%
# replace... geojson-continent-borders, geojson-africa-states; geojson-northamerica-states
geojson_dir = os.path.join(home_dir, f"{geojson_folder_dic[user_spatial]}", "")

geojson_names = []
for (dir_path, dir_names, file_names) in os.walk(geojson_dir):  # give the path
    geojson_names.extend(file_names)
print(geojson_names)
print(os.getcwd())
# Out:
# ['0_Indonesia.geojson', '10_Bhutan.geojson', '11_Oman.geojson', '12_Uzbekistan.geojson', '13_Kazakhstan.geojson', '14_Tajikistan.geojson', '15_Mongolia.geojson', '16_Russia.geojson', '17_Vietnam.geojson', '18_Cambodia.geojson', '19_United Arab Emirates.geojson', '1_Malaysia.geojson', '20_Georgia.geojson', '21_Azerbaijan.geojson', '22_Turkey.geojson', '23_Laos.geojson', '24_Kyrgyzstan.geojson', '25_Armenia.geojson', '26_Iraq.geojson', '27_Iran.geojson', '28_Qatar.geojson', '29_Saudi Arabia.geojson', '2_Cyprus.geojson', '30_Pakistan.geojson', '31_Thailand.geojson', '32_Kuwait.geojson', '33_Timor-Leste.geojson', '34_Brunei.geojson', '35_Myanmar.geojson', '36_Bangladesh.geojson', '37_Afghanistan.geojson', '38_Turkmenistan.geojson', '39_Jordan.geojson', '3_India.geojson', '40_Nepal.geojson', '41_Yemen.geojson', '42_N. Cyprus.geojson', '43_Cyprus U.N. Buffer Zone.geojson', '44_Siachen Glacier.geojson', '45_Philippines.geojson', '46_Sri Lanka.geojson', '47_Taiwan.geojson', '48_Japan.geojson', '49_Singapore.geojson', '4_China.geojson', '50_Bahrain.geojson', '51_Spratly Is..geojson', '52_Scarborough Reef.geojson', '5_Israel.geojson', '6_Lebanon.geojson', '7_Syria.geojson', '8_South Korea.geojson', '9_North Korea.geojson']
# c:\Users\milan\OneDrive - MUNI\VŠ\PhD\Zahraniční stáž\Work\HeiGIT_notebooks\analysis\ai-assisted-osm-mapping-stats

# %%
geojson_names_2 = geojson_names

id_name_dic = {int(re.search(r'^\d+', k)[0]): re.search(r'\_.+\.', v)[0][1:-1]
                for k, v in zip(geojson_names, geojson_names_2)}
id_name_ser = pd.Series(id_name_dic)
id_name_df = pd.DataFrame(id_name_ser, columns=["name"])
id_name_df = id_name_df.reset_index().rename(columns={"index": "id"})
id_name_df["id"] = id_name_df["id"].astype(int)
# id_name_df

# %%
id_name_df
# Out:
#     id                     name
# 0    0                Indonesia
# 1   10                   Bhutan
# 2   11                     Oman
# 3   12               Uzbekistan
# 4   13               Kazakhstan
# 5   14               Tajikistan
# 6   15                 Mongolia
# 7   16                   Russia
# 8   17                  Vietnam
# 9   18                 Cambodia
# 10  19     United Arab Emirates
# 11   1                 Malaysia
# 12  20                  Georgia
# 13  21               Azerbaijan
# 14  22                   Turkey
# 15  23                     Laos
# 16  24               Kyrgyzstan
# 17  25                  Armenia
# 18  26                     Iraq
# 19  27                     Iran
# 20  28                    Qatar
# 21  29             Saudi Arabia
# 22   2                   Cyprus
# 23  30                 Pakistan
# 24  31                 Thailand
# 25  32                   Kuwait
# 26  33              Timor-Leste
# 27  34                   Brunei
# 28  35                  Myanmar
# 29  36               Bangladesh
# 30  37              Afghanistan
# 31  38             Turkmenistan
# 32  39                   Jordan
# 33   3                    India
# 34  40                    Nepal
# 35  41                    Yemen
# 36  42                N. Cyprus
# 37  43  Cyprus U.N. Buffer Zone
# 38  44          Siachen Glacier
# 39  45              Philippines
# 40  46                Sri Lanka
# 41  47                   Taiwan
# 42  48                    Japan
# 43  49                Singapore
# 44   4                    China
# 45  50                  Bahrain
# 46  51              Spratly Is.
# 47  52         Scarborough Reef
# 48   5                   Israel
# 49   6                  Lebanon
# 50   7                    Syria
# 51   8              South Korea
# 52   9              North Korea

# %%
# merge df with region names based on ids
ns_df = ns_df.merge(id_name_df, how="left", left_on="feature",
               right_on="id")
ns_df.head(20)
# Out:
#     feature        source             timestamp         value  year  \
# 0         0     remainder  2018-01-01T00:00:00Z  4.125735e+08  2018
# 1         0     remainder  2019-01-01T00:00:00Z  7.293357e+08  2019
# 2         0     remainder  2020-01-01T00:00:00Z  1.096717e+09  2020
# 3         0     remainder  2021-01-01T00:00:00Z  1.206910e+09  2021
# 4         0     remainder  2022-01-01T00:00:00Z  1.246754e+09  2022
# 5         0     remainder  2023-01-01T00:00:00Z  1.255846e+09  2023
# 6         0  source=maxar  2018-01-01T00:00:00Z  0.000000e+00  2018
# 7         0  source=maxar  2019-01-01T00:00:00Z  0.000000e+00  2019
# 8         0  source=maxar  2020-01-01T00:00:00Z  8.588360e+03  2020
# 9         0  source=maxar  2021-01-01T00:00:00Z  3.416454e+04  2021
# 10        0  source=maxar  2022-01-01T00:00:00Z  2.673150e+06  2022
# 11        0  source=maxar  2023-01-01T00:00:00Z  3.060946e+06  2023
# 12       10     remainder  2018-01-01T00:00:00Z  9.869636e+06  2018
# 13       10     remainder  2019-01-01T00:00:00Z  1.086915e+07  2019
# 14       10     remainder  2020-01-01T00:00:00Z  1.187202e+07  2020
# 15       10     remainder  2021-01-01T00:00:00Z  1.222454e+07  2021
# 16       10     remainder  2022-01-01T00:00:00Z  2.416333e+07  2022
# 17       10     remainder  2023-01-01T00:00:00Z  2.530533e+07  2023
# 18       10  source=maxar  2018-01-01T00:00:00Z  0.000000e+00  2018
# 19       10  source=maxar  2019-01-01T00:00:00Z  0.000000e+00  2019
#
#         value_km  id       name
# 0   4.125735e+05   0  Indonesia
# 1   7.293357e+05   0  Indonesia
# 2   1.096717e+06   0  Indonesia
# 3   1.206910e+06   0  Indonesia
# 4   1.246754e+06   0  Indonesia
# 5   1.255846e+06   0  Indonesia
# 6   0.000000e+00   0  Indonesia
# 7   0.000000e+00   0  Indonesia
# 8   8.588360e+00   0  Indonesia
# 9   3.416454e+01   0  Indonesia
# 10  2.673150e+03   0  Indonesia
# 11  3.060946e+03   0  Indonesia
# 12  9.869636e+03  10     Bhutan
# 13  1.086915e+04  10     Bhutan
# 14  1.187202e+04  10     Bhutan
# 15  1.222454e+04  10     Bhutan
# 16  2.416333e+04  10     Bhutan
# 17  2.530533e+04  10     Bhutan
# 18  0.000000e+00  10     Bhutan
# 19  0.000000e+00  10     Bhutan

# %%
ns_df.loc[ns_df.isna().any(axis=1),:]
# Out:
# Empty DataFrame
# Columns: [feature, source, timestamp, value, year, value_km, id, name]
# Index: []

# %%
# ns_df.sort_values(by=["value"], ascending=False, inplace=False).head(20)

# %% [markdown]
# #### Data preparation and filtering

# %%
# get the number of AI Microsoft (source=microsoft/BuildingFootprints) / manually mapped (remainder) buildings for every year
grouped = ns_df.groupby(["name", "year"])["value"].sum()
# grouped

# %%
# merge the DataFrame with groupBy DataFrame and compute the percentage
merged_data = ns_df.merge(grouped, on=["name", 'year'], how='left', )
merged_data = merged_data.rename(columns={"value_x":"len_of_roads", "value_y":"total_roads"})
merged_data["percentage"] = (merged_data["len_of_roads"] / merged_data["total_roads"]) * 100
# merged_data.head(10)

# %%
# percentage verification
merged_data.groupby(["name", "year"])["percentage"].sum()
# Out:
# name         year
# Afghanistan  2018    100.0
#              2019    100.0
#              2020    100.0
#              2021    100.0
#              2022    100.0
#                      ...
# Yemen        2019    100.0
#              2020    100.0
#              2021    100.0
#              2022    100.0
#              2023    100.0
# Name: percentage, Length: 318, dtype: float64

# %%
ns_df_rem = merged_data.loc[merged_data["source"] == "remainder", :]
ns_df_ai = merged_data.loc[merged_data["source"] == "source=maxar", :]

# %%
ns_df_rem_sel = ns_df_rem.groupby("name")[["len_of_roads", "year", "percentage", "total_roads"]].last().reset_index()
ns_df_ai_sel = ns_df_ai.groupby("name")[["len_of_roads", "year", "percentage", "total_roads"]].last().reset_index()
ns_df_ai_sel.head()
# Out:
#           name  len_of_roads  year  percentage   total_roads
# 0  Afghanistan   16340195.25  2023    8.026059  2.035893e+08
# 1      Armenia       9618.81  2023    0.016120  5.967088e+07
# 2   Azerbaijan     315971.85  2023    0.333903  9.462997e+07
# 3      Bahrain        322.18  2023    0.005814  5.541255e+06
# 4   Bangladesh    5615375.52  2023    2.931745  1.915370e+08

# %%
ns_df_rem_sel.head()
# Out:
#           name  len_of_roads  year  percentage   total_roads
# 0  Afghanistan  1.872491e+08  2023   91.973941  2.035893e+08
# 1      Armenia  5.966126e+07  2023   99.983880  5.967088e+07
# 2   Azerbaijan  9.431400e+07  2023   99.666097  9.462997e+07
# 3      Bahrain  5.540933e+06  2023   99.994186  5.541255e+06
# 4   Bangladesh  1.859216e+08  2023   97.068255  1.915370e+08

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
s_df.head(2)
# Out:
#   SOVEREIGNT  LEVEL               TYPE      ADMIN       NAME CONTINENT  \
# 0  Indonesia      2  Sovereign country  Indonesia  Indonesia      Asia
# 1   Malaysia      2  Sovereign country   Malaysia   Malaysia      Asia
#
#      NAME_EN                                           geometry
# 0  Indonesia  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...
# 1   Malaysia  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...

# %%
merged_d_rem = s_df.merge(ns_df_rem_sel, how="left",
                          left_on="NAME", right_on="name").rename(columns={"name_y": "added_name"})  # change left_on
merged_d_ai = s_df.merge(ns_df_ai_sel, how="left",
                         left_on="NAME", right_on="name").rename(columns={"name_y": "added_name"})  # change left_on
merged_d_rem.head(2)
# Out:
#   SOVEREIGNT  LEVEL               TYPE      ADMIN       NAME CONTINENT  \
# 0  Indonesia      2  Sovereign country  Indonesia  Indonesia      Asia
# 1   Malaysia      2  Sovereign country   Malaysia   Malaysia      Asia
#
#      NAME_EN                                           geometry       name  \
# 0  Indonesia  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...  Indonesia
# 1   Malaysia  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...   Malaysia
#
#    len_of_roads    year  percentage   total_roads
# 0  1.255846e+09  2023.0   99.756857  1.258907e+09
# 1  3.256459e+08  2023.0   99.796276  3.263106e+08

# %%
# verify the merge is successful
merged_d_rem.loc[merged_d_rem.isna().any(axis=1),:]
# Out:
#           SOVEREIGNT  LEVEL           TYPE             ADMIN  \
# 52  Scarborough Reef      2  Indeterminate  Scarborough Reef
#
#                 NAME CONTINENT            NAME_EN  \
# 52  Scarborough Reef      Asia  Scarborough Shoal
#
#                                              geometry name  len_of_roads  \
# 52  POLYGON ((117.75389 15.15437, 117.75569 15.151...  NaN           NaN
#
#     year  percentage  total_roads
# 52   NaN         NaN          NaN

# %%
merged_d_ai.head(2)
# Out:
#   SOVEREIGNT  LEVEL               TYPE      ADMIN       NAME CONTINENT  \
# 0  Indonesia      2  Sovereign country  Indonesia  Indonesia      Asia
# 1   Malaysia      2  Sovereign country   Malaysia   Malaysia      Asia
#
#      NAME_EN                                           geometry       name  \
# 0  Indonesia  MULTIPOLYGON (((117.70361 4.16341, 117.70361 4...  Indonesia
# 1   Malaysia  MULTIPOLYGON (((117.70361 4.16341, 117.69711 4...   Malaysia
#
#    len_of_roads  year  percentage   total_roads
# 0    3060945.91  2023    0.243143  1.258907e+09
# 1     664772.09  2023    0.203724  3.263106e+08

# %%
print(merged_d_rem.columns)
print(merged_d_ai.columns)
# Out:
# Index(['SOVEREIGNT', 'LEVEL', 'TYPE', 'ADMIN', 'NAME', 'CONTINENT', 'NAME_EN',
#        'geometry', 'name', 'len_of_roads', 'year', 'percentage',
#        'total_roads'],
#       dtype='object')
# Index(['SOVEREIGNT', 'LEVEL', 'TYPE', 'ADMIN', 'NAME', 'CONTINENT', 'NAME_EN',
#        'geometry', 'name', 'len_of_roads', 'year', 'percentage',
#        'total_roads'],
#       dtype='object')

# %% [markdown]
# #### Export the data into layers

# %%
os.getcwd()
# Out:
# 'c:\\Users\\milan\\OneDrive - MUNI\\VŠ\\PhD\\Zahraniční stáž\\Work\\HeiGIT_notebooks\\analysis\\ai-assisted-osm-mapping-stats'

# %%
# change name of the layer
merged_d_rem.to_file(f"maps/shp/mm_roads_{geojson_folder_dic[user_json_spec][8:]}_18-21.shp", driver='ESRI Shapefile')
# Out:
# C:\Users\milan\AppData\Local\Temp\ipykernel_27180\3317112753.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   merged_d_rem.to_file(f"maps/shp/mm_roads_{geojson_folder_dic[user_json_spec][8:]}_18-21.shp", driver='ESRI Shapefile')

# %%
# change name of the layer
merged_d_ai.to_file(f"maps/shp/ai_roads_{geojson_folder_dic[user_json_spec][8:]}_18-21.shp", driver='ESRI Shapefile')
# Out:
# C:\Users\milan\AppData\Local\Temp\ipykernel_27180\2868847148.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   merged_d_ai.to_file(f"maps/shp/ai_roads_{geojson_folder_dic[user_json_spec][8:]}_18-21.shp", driver='ESRI Shapefile')
