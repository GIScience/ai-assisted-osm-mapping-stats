# %%
import os
import json
import pandas as pd
import geopandas as gpd
import re
import numpy as np

# %% [markdown]
# ### Definitions

# %%
# dictionary definitions

json_data_dic = {
            0: "roads_continent_data_18-23_ai.json",
            1: "roads_africa_states_18-23_ai.json",
            2: "roads_northamerica_states_18-23_ai.json",
            3: "roads_europe_states_18-23_ai.json",
            4: "roads_asia_states_18-23_ai.json",
            }
shp_dic = {
            0: "contionents-borders.shp",
            1: "africa-states-borders.shp",
            2: "northamerica-states-borders.shp",
            3: "europe-states-borders.shp",
            4: "asia-states-borders.shp",
                      }

geojson_folder_dic = {
                    0: "geojson-continent-states",
                    1: "geojson-africa-states",
                    2: "geojson-northamerica-states",
                    3: "geojson-europe-states",
                    4: "geojson-asia-states",
                      }

# %%
# user input definition - json data

while True:
    try:
        user_json_spec = int(input("Which data do you want to join?\
                            Enter a number:\
                            0 for roads by continents (2018–2023),\
                            1 for roads by Africa states (2018–2023),\
                            2 for roads by North-Central America states (2018–2023),\
                            3 for roads by Europe states (2018–2023),\
                            4 for roads by Asia states (2018–2023),\
                                :"
                                ))
    except ValueError:
        print("Please enter a number.")
        continue
    if user_json_spec not in range(len(json_data_dic)):
        print(f"Please enter one of these numbers: {json_data_dic.keys()}.")
        continue
    break

# %%
# user input definition - spatial data to conect

while True:
    try:
        user_spatial = int(input("Which data do you want to plot?\
                            Enter 0 for stats by continents (2018–2023),\
                            1 for stats by Africa states (2018–2023),\
                            2 for stats by North-Central America states (2018–2023),\
                            3 for stats by Europe states (2018–2023),\
                            4 for stats by Asia states (2018–2023):"
                                ))
    except ValueError:
        print("Please enter a number.")
        continue
    if user_spatial not in range(len(shp_dic)):
        print(f"Please enter one of these numbers: {shp_dic.keys()}.")
        continue
    break

# %% [markdown]
# #### Read the downloaded/nonspatial and spatial data

# %%
os.chdir('..')
home_dir = os.getcwd()
ns_d_path = os.path.join(home_dir, "downloaded-data", "")
s_d_path = os.path.join(home_dir, "shp", "")

# %%
# replace... blds_continents_data_18-23_ai.json; blds_africa_states_18-23_ai.json; blds_northamerica_states_18-23_ai.json
with open(f"{ns_d_path}{json_data_dic[user_json_spec]}", "r") as f:
    ns_d = json.load(f)
# ns_d

# %%
ns_d
# Out:
# [[{'groupByObject': [0, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 742852532.54},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 760699085.41},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 783185595.45},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 814566574.98},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 846346134.27},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 869777221.85}]},
#   {'groupByObject': [0, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 26099.16},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 508688.76},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 557589.33},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 644999.82}]}],
#  [{'groupByObject': [10, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 212846445.12},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 232228987.49},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 240076400.25},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 254944095.37},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 266442030.06},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 274944586.64}]},
#   {'groupByObject': [10, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 7617.07},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 7239.89},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 7684.86}]}],
#  [{'groupByObject': [11, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 437711193.48},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 467525041.32},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 491380229.17},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 523107300.4},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 561748033.46},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 592858125.2}]},
#   {'groupByObject': [11, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 68759.47},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 119527.01},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 133353.56}]}],
#  [{'groupByObject': [12, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 387289746.72},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 420212383.77},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 442753034.6},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 465671916.67},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 485796782.62},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 501303811.88}]},
#   {'groupByObject': [12, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 15346.17},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 31571.28},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 76799.72}]}],
#  [{'groupByObject': [13, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value':

#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 303412407.23}]},
#   {'groupByObject': [3, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 5094.47},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 12980.63}]}],
#  [{'groupByObject': [40, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 51040173.8},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 53468912.77},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 61176043.47},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 63751048.8},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 68833978.49},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 72780562.82}]},
#   {'groupByObject': [40, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 934.52},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 1731.34},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 1070.36}]}],
#  [{'groupByObject': [41, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 559.13},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 559.13},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 559.13},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 559.06},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 559.06},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 553.36}]},
#   {'groupByObject': [41, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 0.0}]}],
#  [{'groupByObject': [42, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 30522436.98},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 32262478.13},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 32818178.45},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 33755777.48},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 34242905.66},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 34802651.0}]},
#   {'groupByObject': [42, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 9909.87},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 9909.87},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 9906.43}]}],
#  [{'groupByObject': [43, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 3163557.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 3172073.16},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 3200515.97},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 3243372.74},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 3275618.56},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 3324223.51}]},
#   {'groupByObject': [43, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 0.0}]}],
#  [{'groupByObject': [4, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 238030744.96},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 243746101.94},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 249793044.43},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 257021820.54},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 263037377.24},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 269105540.46}]},
#   {'groupByObject': [4, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 248.15},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 248.15},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 520.6}]}],
#  [{'groupByObject': [5, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 110731423.84},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 115902800.79},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 119330912.97},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 126603628.51},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 130915842.24},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 133801714.46}]},
#   {'groupByObject': [5, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 1975.17},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 1975.17}]}],
#  [{'groupByObject': [6, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 269081748.85},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 280505351.58},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 291918676.66},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 303104252.78},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 310059565.9},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 317662043.31}]},
#   {'groupByObject': [6, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 1433.72},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 2068.17},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 10038.4},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 14958.26}]}],
#  [{'groupByObject': [7, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 2079981306.96},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 2113747480.79},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 2144786053.38},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 2187508855.83},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 2224031669.04},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 2253637053.29}]},
#   {'groupByObject': [7, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 359762.59},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 368889.44},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 330206.33},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 332473.39}]}],
#  [{'groupByObject': [8, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 61950306.72},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 63094396.02},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 64772650.9},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 66499118.15},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 69502908.78},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 72949281.36}]},
#   {'groupByObject': [8, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 135.34},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 135.34},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 1745.93},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 8126.17}]}],
#  [{'groupByObject': [9, 'remainder'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 74822133.14},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 78171267.82},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 82617961.48},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 88161747.72},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 96203013.29},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 99472548.92}]},
#   {'groupByObject': [9, 'source=maxar'],
#    'result': [{'timestamp': '2018-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2019-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2020-01-01T00:00:00Z', 'value': 0.0},
#     {'timestamp': '2021-01-01T00:00:00Z', 'value': 19134.92},
#     {'timestamp': '2022-01-01T00:00:00Z', 'value': 35057.22},
#     {'timestamp': '2023-01-01T00:00:00Z', 'value': 204832.04}]}]]

# %%
os.getcwd()
# Out:
# 'c:\\Users\\milan\\OneDrive - MUNI\\VŠ\\PhD\\Zahraniční stáž\\Work\\HeiGIT_notebooks\\analysis\\ai-assisted-osm-mapping-stats'

# %%
# change name of the layer - africa-states-borders.shp; northamerica-states-borders.shp

s_df = gpd.read_file(f"{s_d_path}{shp_dic[user_spatial]}")
# s_df["s_id"] = s_df.index
s_df.head()
# Out:
#        SOVEREIGNT  LEVEL               TYPE           ADMIN            NAME  \
# 0  United Kingdom      1        Sovereignty  United Kingdom  United Kingdom
# 1          France      1        Sovereignty          France          France
# 2         Ukraine      2  Sovereign country         Ukraine         Ukraine
# 3         Belarus      2  Sovereign country         Belarus         Belarus
# 4     Netherlands      1        Sovereignty     Netherlands     Netherlands
#
#           NAME_EN                                           geometry
# 0  United Kingdom  MULTIPOLYGON (((33.78094 34.97635, 33.76043 34...
# 1          France  MULTIPOLYGON (((-54.11153 2.11427, -54.13491 2...
# 2         Ukraine  MULTIPOLYGON (((31.76434 52.10057, 31.82584 52...
# 3         Belarus  POLYGON ((23.60624 51.51740, 23.60231 51.53078...
# 4     Netherlands  MULTIPOLYGON (((-63.10700 18.06212, -63.08589 ...

# %% [markdown]
# #### Edit the obtained data into desired shape to create a DataFrame

# %%
d = {
    "feature": [],
    "source": [],
    "timestamp": [],
    "value": []
}

# %%
for region in ns_d:
    for dic1 in region:
        feature, source = dic1["groupByObject"][0], dic1["groupByObject"][1]
        for res in dic1["result"]:
            d["feature"].append(feature)
            d["source"].append(source)
            d["timestamp"].append(res["timestamp"])
            d["value"].append(res["value"])

ns_df = pd.DataFrame(d)
# ns_df

# %%
# extract only the year
ns_df["year"] = pd.to_datetime(ns_df["timestamp"]).dt.year

# convert meters to kilometers
ns_df["value"] = ns_df["value"] / 1000

# %%
ns_df
# Out:
#      feature        source             timestamp         value  year
# 0          0     remainder  2018-01-01T00:00:00Z  742852.53254  2018
# 1          0     remainder  2019-01-01T00:00:00Z  760699.08541  2019
# 2          0     remainder  2020-01-01T00:00:00Z  783185.59545  2020
# 3          0     remainder  2021-01-01T00:00:00Z  814566.57498  2021
# 4          0     remainder  2022-01-01T00:00:00Z  846346.13427  2022
# ..       ...           ...                   ...           ...   ...
# 523        9  source=maxar  2019-01-01T00:00:00Z       0.00000  2019
# 524        9  source=maxar  2020-01-01T00:00:00Z       0.00000  2020
# 525        9  source=maxar  2021-01-01T00:00:00Z      19.13492  2021
# 526        9  source=maxar  2022-01-01T00:00:00Z      35.05722  2022
# 527        9  source=maxar  2023-01-01T00:00:00Z     204.83204  2023
#
# [528 rows x 5 columns]

# %% [markdown]
# #### Append the names of the regions and numbers to the DataFrame

# %%
# replace... geojson-continent-borders, geojson-africa-states; geojson-northamerica-states
geojson_dir = os.path.join(home_dir, f"{geojson_folder_dic[user_spatial]}", "")

geojson_names = []
for (dir_path, dir_names, file_names) in os.walk(geojson_dir):  # give the path
    geojson_names.extend(file_names)
print(geojson_names)
print(os.getcwd())
# Out:
# ['0_United Kingdom.geojson', '10_Norway.geojson', '11_Sweden.geojson', '12_Finland.geojson', '13_Luxembourg.geojson', '14_Belgium.geojson', '15_North Macedonia.geojson', '16_Albania.geojson', '17_Kosovo.geojson', '18_Spain.geojson', '19_Denmark.geojson', '1_France.geojson', '20_Romania.geojson', '21_Hungary.geojson', '22_Slovakia.geojson', '23_Poland.geojson', '24_Ireland.geojson', '25_Greece.geojson', '26_Austria.geojson', '27_Italy.geojson', '28_Switzerland.geojson', '29_Liechtenstein.geojson', '2_Ukraine.geojson', '30_Serbia.geojson', '31_Croatia.geojson', '32_Slovenia.geojson', '33_Bulgaria.geojson', '34_San Marino.geojson', '35_Monaco.geojson', '36_Andorra.geojson', '37_Montenegro.geojson', '38_Bosnia and Herz..geojson', '39_Portugal.geojson', '3_Belarus.geojson', '40_Moldova.geojson', '41_Vatican.geojson', '42_Iceland.geojson', '43_Malta.geojson', '4_Netherlands.geojson', '5_Lithuania.geojson', '6_Czechia.geojson', '7_Germany.geojson', '8_Estonia.geojson', '9_Latvia.geojson']
# c:\Users\milan\OneDrive - MUNI\VŠ\PhD\Zahraniční stáž\Work\HeiGIT_notebooks\analysis\ai-assisted-osm-mapping-stats

# %%
geojson_names_2 = geojson_names

id_name_dic = {int(re.search(r'^\d+', k)[0]): re.search(r'\_.+\.', v)[0][1:-1]
                for k, v in zip(geojson_names, geojson_names_2)}
id_name_ser = pd.Series(id_name_dic)
id_name_df = pd.DataFrame(id_name_ser, columns=["name"])
id_name_df = id_name_df.reset_index().rename(columns={"index": "id"})
id_name_df["id"] = id_name_df["id"].astype(int)
# id_name_df

# %%
id_name_df
# Out:
#     id              name
# 0    0    United Kingdom
# 1   10            Norway
# 2   11            Sweden
# 3   12           Finland
# 4   13        Luxembourg
# 5   14           Belgium
# 6   15   North Macedonia
# 7   16           Albania
# 8   17            Kosovo
# 9   18             Spain
# 10  19           Denmark
# 11   1            France
# 12  20           Romania
# 13  21           Hungary
# 14  22          Slovakia
# 15  23            Poland
# 16  24           Ireland
# 17  25            Greece
# 18  26           Austria
# 19  27             Italy
# 20  28       Switzerland
# 21  29     Liechtenstein
# 22   2           Ukraine
# 23  30            Serbia
# 24  31           Croatia
# 25  32          Slovenia
# 26  33          Bulgaria
# 27  34        San Marino
# 28  35            Monaco
# 29  36           Andorra
# 30  37        Montenegro
# 31  38  Bosnia and Herz.
# 32  39          Portugal
# 33   3           Belarus
# 34  40           Moldova
# 35  41           Vatican
# 36  42           Iceland
# 37  43             Malta
# 38   4       Netherlands
# 39   5         Lithuania
# 40   6           Czechia
# 41   7           Germany
# 42   8           Estonia
# 43   9            Latvia

# %%
# merge df with region names based on ids
ns_df = ns_df.merge(id_name_df, how="left", left_on="feature",
               right_on="id")
ns_df.head(20)
# Out:
#     feature        source             timestamp         value  year  id  \
# 0         0     remainder  2018-01-01T00:00:00Z  742852.53254  2018   0
# 1         0     remainder  2019-01-01T00:00:00Z  760699.08541  2019   0
# 2         0     remainder  2020-01-01T00:00:00Z  783185.59545  2020   0
# 3         0     remainder  2021-01-01T00:00:00Z  814566.57498  2021   0
# 4         0     remainder  2022-01-01T00:00:00Z  846346.13427  2022   0
# 5         0     remainder  2023-01-01T00:00:00Z  869777.22185  2023   0
# 6         0  source=maxar  2018-01-01T00:00:00Z       0.00000  2018   0
# 7         0  source=maxar  2019-01-01T00:00:00Z       0.00000  2019   0
# 8         0  source=maxar  2020-01-01T00:00:00Z      26.09916  2020   0
# 9         0  source=maxar  2021-01-01T00:00:00Z     508.68876  2021   0
# 10        0  source=maxar  2022-01-01T00:00:00Z     557.58933  2022   0
# 11        0  source=maxar  2023-01-01T00:00:00Z     644.99982  2023   0
# 12       10     remainder  2018-01-01T00:00:00Z  212846.44512  2018  10
# 13       10     remainder  2019-01-01T00:00:00Z  232228.98749  2019  10
# 14       10     remainder  2020-01-01T00:00:00Z  240076.40025  2020  10
# 15       10     remainder  2021-01-01T00:00:00Z  254944.09537  2021  10
# 16       10     remainder  2022-01-01T00:00:00Z  266442.03006  2022  10
# 17       10     remainder  2023-01-01T00:00:00Z  274944.58664  2023  10
# 18       10  source=maxar  2018-01-01T00:00:00Z       0.00000  2018  10
# 19       10  source=maxar  2019-01-01T00:00:00Z       0.00000  2019  10
#
#               name
# 0   United Kingdom
# 1   United Kingdom
# 2   United Kingdom
# 3   United Kingdom
# 4   United Kingdom
# 5   United Kingdom
# 6   United Kingdom
# 7   United Kingdom
# 8   United Kingdom
# 9   United Kingdom
# 10  United Kingdom
# 11  United Kingdom
# 12          Norway
# 13          Norway
# 14          Norway
# 15          Norway
# 16          Norway
# 17          Norway
# 18          Norway
# 19          Norway

# %%
ns_df.loc[ns_df.isna().any(axis=1),:]
# Out:
# Empty DataFrame
# Columns: [feature, source, timestamp, value, year, id, name]
# Index: []

# %%
# ns_df.sort_values(by=["value"], ascending=False, inplace=False).head(20)

# %% [markdown]
# #### Data preparation and filtering

# %%
# get the number of AI Microsoft (source=microsoft/BuildingFootprints) / manually mapped (remainder) buildings for every year
grouped = ns_df.groupby(["source", "year"])["value"].sum()
# grouped

# %%
# merge the DataFrame with groupBy DataFrame and compute the percentage
merged_data = ns_df.merge(grouped, on=["source", 'year'], how='left', )
merged_data = merged_data.rename(columns={"value_x":"len_of_roads", "value_y":"total_roads"})
merged_data["percentage"] = (merged_data["len_of_roads"] / merged_data["total_roads"]) * 100
# merged_data.head(10)

# %%
# percentage verification
merged_data.groupby(["source", "year"])["percentage"].sum()
# Out:
# source        year
# remainder     2018    100.0
#               2019    100.0
#               2020    100.0
#               2021    100.0
#               2022    100.0
#               2023    100.0
# source=maxar  2018      0.0
#               2019      0.0
#               2020    100.0
#               2021    100.0
#               2022    100.0
#               2023    100.0
# Name: percentage, dtype: float64

# %%
ns_df_rem = merged_data.loc[merged_data["source"] == "remainder", :]
ns_df_ai = merged_data.loc[merged_data["source"] == "source=maxar", :]

# %%
ns_df_rem_sel = ns_df_rem.groupby("name")[["len_of_roads", "year", "percentage", "total_roads"]].last().reset_index()
ns_df_ai_sel = ns_df_ai.groupby("name")[["len_of_roads", "year", "percentage", "total_roads"]].last().reset_index()
ns_df_ai_sel.head()
# Out:
#       name  len_of_roads  year  percentage  total_roads
# 0  Albania      40.85834  2023    0.437100    9347.5901
# 1  Andorra       0.00000  2023    0.000000    9347.5901
# 2  Austria       1.76416  2023    0.018873    9347.5901
# 3  Belarus      12.98063  2023    0.138866    9347.5901
# 4  Belgium       0.45483  2023    0.004866    9347.5901

# %%
ns_df_rem_sel.head()
# Out:
#       name  len_of_roads  year  percentage   total_roads
# 0  Albania   48914.42838  2023    0.298112  1.640806e+07
# 1  Andorra    1635.76901  2023    0.009969  1.640806e+07
# 2  Austria  436386.41305  2023    2.659585  1.640806e+07
# 3  Belarus  303412.40723  2023    1.849166  1.640806e+07
# 4  Belgium  194746.62977  2023    1.186896  1.640806e+07

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

# %%
s_df.head(2)
# Out:
#        SOVEREIGNT  LEVEL         TYPE           ADMIN            NAME  \
# 0  United Kingdom      1  Sovereignty  United Kingdom  United Kingdom
# 1          France      1  Sovereignty          France          France
#
#           NAME_EN                                           geometry
# 0  United Kingdom  MULTIPOLYGON (((33.78094 34.97635, 33.76043 34...
# 1          France  MULTIPOLYGON (((-54.11153 2.11427, -54.13491 2...

# %%
merged_d_rem = s_df.merge(ns_df_rem_sel, how="left",
                          left_on="NAME", right_on="name").rename(columns={"name_y": "added_name"})  # change left_on
merged_d_ai = s_df.merge(ns_df_ai_sel, how="left",
                         left_on="NAME", right_on="name").rename(columns={"name_y": "added_name"})  # change left_on
merged_d_rem.head(2)
# Out:
#        SOVEREIGNT  LEVEL         TYPE           ADMIN            NAME  \
# 0  United Kingdom      1  Sovereignty  United Kingdom  United Kingdom
# 1          France      1  Sovereignty          France          France
#
#           NAME_EN                                           geometry  \
# 0  United Kingdom  MULTIPOLYGON (((33.78094 34.97635, 33.76043 34...
# 1          France  MULTIPOLYGON (((-54.11153 2.11427, -54.13491 2...
#
#              name  len_of_roads  year  percentage   total_roads
# 0  United Kingdom  8.697772e+05  2023    5.300913  1.640806e+07
# 1          France  2.323392e+06  2023   14.160064  1.640806e+07

# %%
# verify the merge is successful
merged_d_rem.loc[merged_d_rem.isna().any(axis=1),:]
# Out:
# Empty GeoDataFrame
# Columns: [SOVEREIGNT, LEVEL, TYPE, ADMIN, NAME, NAME_EN, geometry, name, len_of_roads, year, percentage, total_roads]
# Index: []

# %%
merged_d_ai.head(2)
# Out:
#        SOVEREIGNT  LEVEL         TYPE           ADMIN            NAME  \
# 0  United Kingdom      1  Sovereignty  United Kingdom  United Kingdom
# 1          France      1  Sovereignty          France          France
#
#           NAME_EN                                           geometry  \
# 0  United Kingdom  MULTIPOLYGON (((33.78094 34.97635, 33.76043 34...
# 1          France  MULTIPOLYGON (((-54.11153 2.11427, -54.13491 2...
#
#              name  len_of_roads  year  percentage  total_roads
# 0  United Kingdom     644.99982  2023    6.900172    9347.5901
# 1          France     104.11323  2023    1.113798    9347.5901

# %%
print(merged_d_rem.columns)
print(merged_d_ai.columns)
# Out:
# Index(['SOVEREIGNT', 'LEVEL', 'TYPE', 'ADMIN', 'NAME', 'NAME_EN', 'geometry',
#        'name', 'len_of_roads', 'year', 'percentage', 'total_roads'],
#       dtype='object')
# Index(['SOVEREIGNT', 'LEVEL', 'TYPE', 'ADMIN', 'NAME', 'NAME_EN', 'geometry',
#        'name', 'len_of_roads', 'year', 'percentage', 'total_roads'],
#       dtype='object')

# %% [markdown]
# #### Export the data into layers

# %%
os.getcwd()
# Out:
# 'c:\\Users\\milan\\OneDrive - MUNI\\VŠ\\PhD\\Zahraniční stáž\\Work\\HeiGIT_notebooks\\analysis\\ai-assisted-osm-mapping-stats'

# %%
# change name of the layer
merged_d_rem.to_file(
    f"maps/shp/mm_roads_{geojson_folder_dic[user_json_spec][8:]}.shp", driver='ESRI Shapefile')
# Out:
# C:\Users\milan\AppData\Local\Temp\ipykernel_17392\3533171378.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   merged_d_rem.to_file(

# %%
# change name of the layer
merged_d_ai.to_file(
    f"maps/shp/ai_roads_{geojson_folder_dic[user_json_spec][8:]}.shp", driver='ESRI Shapefile')
# Out:
# C:\Users\milan\AppData\Local\Temp\ipykernel_17392\398913792.py:2: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   merged_d_ai.to_file(
